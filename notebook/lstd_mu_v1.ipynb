# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="white", palette="husl")

# %load_ext autoreload
# %autoreload 2

import numpy as np
import gym
import sys
import os
if "../" not in sys.path:
    sys.path.insert(0, "../")

    
from logger import *
setup_logging(default_level=logging.INFO)

from sklearn import manifold, datasets
from sklearn.utils import check_random_state


from algo.lstd import LSTDQ, LSTDMu, LSPI
from algo.policy import RandomPolicy2, LinearQ2
from algo.fa import LinearQ3
from algo.apprenticeship_learning import ApprenticeshipLearning as AL
from env.simulator import * 
from util.plotting import *
from util.basis import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
env_id = "MountainCar-v0"
env = gym.envs.make(env_id)
state_dim = env.observation_space.shape[0]
# discrete action
action_dim = 1
n_action = env.action_space.n
action_list = range(env.action_space.n)
sim = Simulator(env, state_dim=state_dim, action_dim=action_dim)
# default
s_init = [-0.5, 0]
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
# hack to give us control over the initial state
import types

def new_timelimit_reset(self, s_init=None):
    import time
    self._episode_started_at = time.time()
    self._elapsed_steps = 0
    return self.env.reset(s_init)

def new_reset(self, s_init):
    if s_init is None:
        s_init = [np.random.uniform(-0.6, -0.4), 0]
    self.state = np.array(s_init)
    return np.array(self.state)
env.reset = types.MethodType(new_timelimit_reset, env)
env.env.reset = types.MethodType(new_reset, env.env)
print(env.reset([-.3, 0.3]))
# Out:
# [-0.3  0.3]

# %% [markdown]
# ## define simulator

# %%
include_action = False
# if this is True, then the state space becomes very large
# therefore, a more denser, higher number of phi is needed

p_linear = 2 * n_action
q_linear = 2 * n_action
phi_linear = LinearKernel2(p_linear, n_action, include_action).transform
psi_linear = phi_linear

n_component_list = [10, 10]
gamma_list = [0.5, 30.0]
#gamma_list = [0.5, 5.0, 30.0]
p_rbf =  int(np.sum(n_component_list)) * n_action
q_rbf = int(np.sum(n_component_list)) * n_action

# technically the truly-batch mode should use D to fit rbf kenel
states = np.array([env.observation_space.sample() for x in range(10000)])
phi_rbf = RBFKernel2(states, n_action, p_rbf, n_component_list, gamma_list, include_action).transform
psi_rbf = phi_rbf

precision = 1e-2
eps = 0.01
gamma = 0.99

n_component = 7
add_bias = True
p_gaus = (n_component**2 + int(add_bias)) * n_action 
phi_gaus = GaussianKernel(states, n_action, p_gaus, n_component, include_action, add_bias).transform
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c84a6ad5dcc4> in <module>()
#      26 add_bias = True
#      27 p_gaus = (n_component**2 + int(add_bias)) * n_action
# ---> 28 phi_gaus = GaussianKernel(states, n_action, p_gaus, n_component, include_action, add_bias).transform
#
# ~/Dropbox/master_personal/code_dh/scripts/harvard/courses/mighty-rl/util/basis.py in __init__(self, states, n_action, p, n_component, include_action, add_bias, standardized)
#     183             self._phi = self.fit(scaler.transform(states))
#     184         else:
# --> 185             self._phi = self.fit(states)
#     186
#     187
#
# ~/Dropbox/master_personal/code_dh/scripts/harvard/courses/mighty-rl/util/basis.py in fit(self, states)
#     204
#     205
# --> 206         mus = np.vstack(([mu_x.T], [mu_y.T])).T
#     207         self._mus = mus.reshape(self._n_component**2, 2)
#     208
#
# NameError: name 'mu_x' is not defined

# %%
phi = phi_gaus
p = p_gaus

mdp_solver = LinearQ3(env=env,
                      phi=phi,
                      p=p,
                      action_list=action_list,
                      n_episode=150,
                      epsilon=0.0,
                      epsilon_decay=1.00,
                      gamma=gamma)

pi_expert, stats = mdp_solver.solve(reward_fn=None)
plotting.plot_cost_to_go_mountain_car(env, pi_expert._estimator)
plotting.plot_episode_stats(stats, smoothing_window=10)
# Out:
# /home/dhfromkorea/.local/lib/python3.5/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Step 163 @ Episode 150/150 (-156.0)
# (<matplotlib.figure.Figure at 0x7f8e28ef3240>,
#  <matplotlib.figure.Figure at 0x7f8e26df9978>,
#  <matplotlib.figure.Figure at 0x7f8e26dff320>)

# %% [markdown]
# ## generate trajectories under expert policy (=D)

# %%
class NearExpertPolicy():
    """
    hard-coded near-optimal expert policy
    for mountaincar-v0
    """
    def choose_action(self, s):
        pos, v = s
        c = np.random.uniform(-0.1, 0.1)
        c = 0
        return 0 if v <= c else 2

class OppositeNearExpertPolicy():
    """
    hard-coded near-optimal expert policy
    for mountaincar-v0
    """
    def choose_action(self, s):
        pos, v = s
        c = np.random.uniform(-0.1, 0.1)
        return 0 if v > c else 2
pi_near = NearExpertPolicy()
pi_near_ops = OppositeNearExpertPolicy()
pi_random = RandomPolicy2(action_list)

# %%
# mixed training set
#pi_list = [pi_random, pi_near_ops, pi_near, pi_expert]
#mix_ratio = [0.1, 0.1, 0.1, 0.7]
#sample_size = 100
#D = sim.simulate_mixed(env, pi_list, sample_size, mix_ratio)
#D_mat = Simulator.to_matrix(D)

pi_list = [pi_random, pi_near_ops, pi_near]
mix_ratio = [0.2, 0.2, 0.6]
sample_size = 100
D = sim.simulate_mixed(env, pi_list, sample_size, mix_ratio)
D_mat = Simulator.to_matrix(D)


# pure expert
#D = sim.simulate(pi_expert, 1, 100)
#D_mat = Simulator.to_matrix(D)
# Out:
# Step 158 @ Episode 100/100 (-148.0)

# %%
plot_trajectory_mountain_car(D)

# %%
samples=np.array([env.observation_space.sample() for _ in range(500)])
plt.scatter(samples[:, 0], samples[:, 1])

# %% [markdown]
# ## Monte Carlo $\mu$ vs. LSTD $\mu$
# - given a fixed 20 initial points
# - mu_mc obtained from simulatation
# - mu_lstd learned from D
# - both linear and rbf

# %%
# define policy to evaluate
# easy
#pi_eval = pi_expert
# easy
pi_eval = pi_expert
# difficult (likely)
#pi_eval = pi_near_ops

# set of initial points to test for
zeros = np.zeros(20)
s_init_list = np.array([ [pos, v] for pos, v in zip(np.linspace(-0.6, -0.4, 20), zeros)])

# %% [markdown]
# ## run mu_mc with linear

# %%
# montecarlo roll outs
sample_size_mc = 50

mu_mc_linear = {}
for s_init in s_init_list:
    mu_mc, epi_len = AL.estimate_mu(env=env,
                            pi_eval=pi_eval,
                            mu_sample_size=sample_size_mc,
                            phi=phi_linear,
                            gamma=gamma,
                            return_epi_len=True,
                            s_init=s_init)
    mu_mc_linear[tuple(s_init)] = mu_mc
# Out:
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples
# INFO:root:estimating mu with 50 samples

# %% [markdown]
# ## run_mu_lstd with linear

# %%
# depends on basis function
eps = 0.001
mu_lstd_linear = {}
for s_init in s_init_list:
    lm_linear = LSTDMu(p=p_linear, q=q_linear, phi=phi_linear, psi=psi_linear, gamma=gamma, eps=eps)
    lm_linear.fit(D=D_mat, pi=pi_eval)
    mu_lstd = lm_linear.predict(s_init, pi_eval.choose_action(s_init))
    mu_lstd_linear[tuple(s_init)] = mu_lstd
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# INFO:root:
# Unfortunately, your original traceback can not be constructed.
# Traceback (most recent call last):
#   File "/home/dhfromkorea/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-ece9b1b07a0c>", line 6, in <module>
#     lm_linear.fit(D=D_mat, pi=pi_eval)
#   File "../algo/lstd.py", line 156, in fit
#     a_next = np.vstack(np.apply_along_axis(pi.choose_action, 1, s_next))
#   File "/usr/local/lib/python3.5/dist-packages/numpy/lib/shape_base.py", line 155, in apply_along_axis
#     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#   File "../algo/fa.py", line 82, in choose_action
#     p = self._action_probs(s)
#   File "../algo/fa.py", line 76, in _action_probs
#     q_values = self._estimator.predict(s)
#   File "../algo/fa.py", line 45, in predict
#     features = self._phi(s, a)[0, l:r]
#   File "../util/basis.py", line 256, in transform
#     phi_sa = np.expand_dims(helper(s, a), axis=0)
#   File "../util/basis.py", line 240, in helper
#     featurized[l:r] = self._phi(s)
#   File "../util/basis.py", line 192, in phi
#     a = np.linspace(c * x.min(), c * x.max(), self._n_component)
#   File "/usr/local/lib/python3.5/dist-packages/numpy/lib/shape_base.py", line 154, in apply_along_axis
#     for ind in inds:
#   File "/usr/local/lib/python3.5/dist-packages/numpy/lib/shape_base.py", line 125, in <genexpr>
#     inds = (ind + (Ellipsis,) for ind in inds)
#   File "/usr/local/lib/python3.5/dist-packages/numpy/lib/index_tricks.py", line 598, in __next__
#     return self._it.multi_index
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dhfromkorea/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dhfromkorea/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/dhfromkorea/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/dhfromkorea/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.5/inspect.py", line 1453, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.5/inspect.py", line 1414, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/dhfromkorea/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 165, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/usr/lib/python3.5/inspect.py", line 672, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.5/inspect.py", line 709, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %% [markdown]
# ## run mu_mc with rbf

# %%
# montecarlo roll outs
sample_size_mc = 50

# set of initial points to test for
mu_mc_rbf = {}
for s_init in s_init_list:
    mu_mc, epi_len = AL.estimate_mu(env=env,
                            pi_eval=pi_eval,
                            mu_sample_size=sample_size_mc,
                            phi=phi_rbf,
                            gamma=gamma,
                            return_epi_len=True,
                            s_init=s_init)
    mu_mc_rbf[tuple(s_init)] = mu_mc

# %% [markdown]
# ## run_mu_lstd with rbf

# %%
# depends on basis function
eps = 0.001
mu_lstd_rbf = {}
for s_init in s_init_list:
    lm_rbf = LSTDMu(p=p_rbf, q=q_rbf, phi=phi_rbf, psi=psi_rbf, gamma=gamma, eps=eps)
    lm_rbf.fit(D=D_mat, pi=pi_eval)
    mu_lstd = lm_rbf.predict(s_init, pi_eval.choose_action(s_init))
    mu_lstd_rbf[tuple(s_init)] = mu_lstd

# %%
def compare_mc_lstd(s_init_list, mu_mc_linear, mu_lstd_linear, mu_mc_rbf, mu_lstd_rbf):
    dist_list_linear = []
    dist_list_rbf = []
    for s_init in s_init_list:
        dist = np.linalg.norm(mu_mc_linear[tuple(s_init)] - mu_lstd_linear[tuple(s_init)], 2)
        dist_list_linear.append(dist)
        dist = np.linalg.norm(mu_mc_rbf[tuple(s_init)] - mu_lstd_rbf[tuple(s_init)], 2)
        dist_list_rbf.append(dist)

    ax = plt.gca()
    ax.plot(s_init_list[:, 0], dist_list_linear, label="linear l2 norm", linestyle='--', marker='o')
    ax.plot(s_init_list[:, 0], dist_list_rbf, label="rbf l2 norm", linestyle='--', marker='o')
    ax.legend()
    plt.show()
    
compare_mc_lstd(s_init_list, mu_mc_linear, mu_lstd_linear, mu_mc_rbf, mu_lstd_rbf)

# %% [markdown]
# ## Monte Carlo $\mu$ vs. LSTD $\mu$

# %%
mu_mc_linear1 = np.array([mu_mc_linear[tuple(s)].flatten() for s in s_init_list])
mu_lstd_linear1 = np.array([mu_lstd_linear[tuple(s)].flatten() for s in s_init_list])
mu_mc_rbf1 = np.array([mu_mc_rbf[tuple(s)].flatten() for s in s_init_list])
mu_lstd_rbf1 = np.array([mu_lstd_rbf[tuple(s)].flatten() for s in s_init_list])

# %%
mu_mc_linear1[1, :]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 7))
plt.suptitle('MC vs. LSTD')

#ax1.set_xlim(-30, 5)
#ax1.set_ylim(-1.5, 1.5)

xx = []
yy = []
for j in range(mu_mc_linear1.shape[0]):
    xx += [np.mean(mu_mc_linear1[j, i]) for i in range(6) if i % 2 == 0]
    yy += [np.mean(mu_mc_linear1[j, i]) for i in range(6) if i % 2 != 0]
ax1.scatter(xx, yy, c='r', label='linear_mc')



xx = []
yy = []
for j in range(mu_lstd_linear1.shape[0]):
    xx += [np.mean(mu_lstd_linear1[j, i]) for i in range(6) if i % 2 == 0]
    yy += [np.mean(mu_lstd_linear1[j, i]) for i in range(6) if i % 2 != 0]
ax1.scatter(xx, yy, c='b', label='linear_lstd')

    
ax1.set_xlabel('Position')
ax1.set_ylabel('Velocity')

tsne1 = manifold.TSNE(n_components=2, init='pca', random_state=0)
trans_data1 = tsne1.fit_transform(mu_mc_rbf1).T

tsne2 = manifold.TSNE(n_components=2, init='pca', random_state=0)
trans_data2 = tsne2.fit_transform(mu_lstd_rbf1).T


#ax2.set_xlim(-250, 250)
#ax2.set_ylim(-250, 250)
ss = ax2.scatter(trans_data1[0], trans_data1[1], c='r', label='rbf_mc')
ss = ax2.scatter(trans_data2[0], trans_data2[1], c='b', label='rbf_lstd')
ax2.set_title("t-SNE of mu_expert_stochastic")
ax2.axis('tight')
#fig.colorbar(ss, ax=ax2)
plt.show()
                 
# u_hat= 1/n sum_{i=1}^n (u_i)
# E[u_hat] = u

# %% [markdown]
# ## apply apprenticeship learning

# %%
## value margin

# %%
results = np.load("data/res_1522884923.4368284")
pi_irl_list = results['solutions']
D_irl = sim.simulate(pi_irl_list[0], n_trial=1, n_episode=50)

# %%
pi_irl_list[0]._phi([0.5, 0.2], 1)

# %%
sns.set(style='white', palette='Blues')

fig = plt.figure(figsize=(10, 10))
plt.xticks(fontsize=15.0)
plt.yticks(fontsize=15.0)

ax = plt.gca()
lines = [[(-0.4, 0.0), (-0.6, 0.0)]]
c = np.array([(1, 0, 0, 1)])
lc = mc.LineCollection(lines, colors='red', linewidths=5)
ax.add_collection(lc)
for episode in D_irl:
    states = []
    for (s, a, r, s_next, done) in episode:
        states.append(s)
    states = np.array(states)
    sc = ax.scatter(states[:,0], states[:,1], c=range(len(states[:,0])), cmap=plt.get_cmap("YlOrRd"), s=7.0)
#ax.axis([-1.2,0.6,-0.07,0.07])
ax.axvline(0.5, c='blue', linewidth=5)
ax.set_xlabel('Position', fontsize=20.0)
ax.set_ylabel('Velocity', fontsize=20.0)
#plt.colorbar(sc)
plt.show()

# %%
from matplotlib import collections  as mc

sns.set(style='white', palette='Blues')

fig, axes = plt.subplots(1, 2, figsize=(20, 10))
plt.xticks(fontsize=15.0)
plt.yticks(fontsize=15.0)

titles = ["Near-expert policy trajectories", "IRL poilcy trajectories"]
for title, ax, trajs_irl in zip(titles, axes, [trajs_expert_near, D_irl]):
    lines = [[(-0.4, 0.0), (-0.6, 0.0)]]
    c = np.array([(1, 0, 0, 1)])
    lc = mc.LineCollection(lines, colors='red', linewidths=5)
    ax.set_title(title, fontsize=20.0)

    ax.add_collection(lc)
    for episode in trajs_irl:
        states = []
        try:
            for s, a, r, s_next, done in episode:
                states.append(s)
        except:
            import pdb;pdb.set_trace()
        states = np.array(states)
        sc = ax.scatter(states[:,0], states[:,1], c=range(len(states[:,0])), cmap=plt.get_cmap("YlOrRd"), s=7.0)
    #ax.axis([-1.2,0.6,-0.07,0.07])
    ax.axvline(0.5, c='blue', linewidth=5)
    ax.set_xlabel('Position', fontsize=20.0)
    ax.set_ylabel('Velocity', fontsize=20.0)
    #plt.colorbar(sc)
plt.show()

# %%
margin_v_collection = results['margin_v']
margin_mu_collection = results['margin_mu']
mu_collection = results['mu']

# %%
ax = plt.gca()
print('e')
for mu_list in mu_collection:
    mu_list = np.array(mu_list)
    #ax.scatter(mu_list[:, 0], mu_list[:, 1], c = range(len(mu_list[:,1])), cmap=plt.get_cmap("YlOrRd"))

mu_exp_list = np.array(estimate_mu_mc(env, pi_expert_near, phi_linear, gamma, 1000))
mu_exp = mu_exp_list.mean(axis=0)
ax.scatter(mu_exp[0], mu_exp[1], c='b')

# %%
print(mu_exp_list.mean(axis=0).shape)
print(mu_exp_list.mean(axis=1)[1])

# %%
from scipy.stats import sem
D_v = np.array(margin_v_collection)
mu_hat = np.mean(D_v, axis=0)
s = sem(D_v, axis=0)
ax = plt.gca()
ax.errorbar(np.arange(D_v.shape[1]), mu_hat, yerr=s, fmt="--o", c='g')
ax.set_title('value margin')
plt.show()

# %%
from scipy.stats import sem
D_mu = np.array(margin_mu_collection)
mu_hat = np.mean(D_mu, axis=0)
s = sem(D_mu, axis=0)
ax = plt.gca()
ax.set_title('feature expectation margin')
ax.errorbar(np.arange(D_mu.shape[1]), mu_hat, yerr=s, fmt="--o", c='b')
plt.show()

# %%
import pickle
from time import time
with open("data/res_{}.pkl".format(time()), "wb") as f:
    pickle.dump({'name': 'james'}, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ##
# - number of samples
# - fitted reward vs. true reward
# - violation of actions
# - trajectory matching
# - margin
